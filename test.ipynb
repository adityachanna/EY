# %%
from langchain.agents import create_agent
from langchain.chat_models import init_chat_model
from langchain_tavily import TavilySearch
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
import os 
load_dotenv()
# Out:
# True

# %%
llm = ChatOpenAI(

  api_key=os.getenv("OPENROUTER_API_KEY"),

  base_url="https://openrouter.ai/api/v1",

  model="amazon/nova-2-lite-v1:free",
  temperature=0.3,
  )

# %%
PlanLLM = ChatOpenAI(

  api_key=os.getenv("OPENROUTER_API_KEY"),

  base_url="https://openrouter.ai/api/v1",

  model='tngtech/deepseek-r1t2-chimera:free',
  temperature=0.3)

# %%
small_model=init_chat_model(model='models/gemini-flash-lite-latest',model_provider='google_genai',temperature=0.3,thinking_budget=0)

# %%
medium_model=init_chat_model(model='moonshotai/kimi-k2-instruct-0905',model_provider='groq',temperature=0)

# %%
result=llm.invoke("What is capital of france? and tell me capital of france")

# %%
result
# Out:
# AIMessage(content='### Answer:  \nThe **capital of France is Paris**.  \n\nParis has been the capital of France for centuries and serves as the country\'s political, economic, cultural, and artistic center. It is renowned for landmarks like the Eiffel Tower, Louvre Museum, Notre-Dame Cathedral, and the Champs-Élysées.  \n\n**Key facts about Paris:**  \n- **Official name:** Paris (French: *Paris*)  \n- **Role:** Seat of the French government, including the President’s official residence (Élysée Palace).  \n- **Population:** Over 2 million people in the city proper (Paris proper), making it one of Europe’s most populous capital cities.  \n- **Symbolic significance:** Often called the "City of Light" (*La Ville Lumière*) for its historical role in the Age of Enlightenment and its early adoption of street lighting.  \n\nSo, whether you ask "What is the capital of France?" or "Tell me the capital of France," the answer is **Paris**. 🇫🇷', additional_kwargs={'refusal': None}, response_metad
# ...

# %%
from deepagents import create_deep_agent
agent = create_deep_agent(model=llm)

# %%
import os
from typing import Literal
from tavily import TavilyClient
from deepagents import create_deep_agent

tavily_client = TavilyClient(api_key=os.environ["TAVILY_API_KEY"])

def internet_search(
    query: str,
    max_results: int = 7,
    search_depth: Literal["basic", "advanced"] = "basid",   
    topic: Literal["general", "pharma", "finance"] = "general",
    include_raw_content: bool = False,
):
    """Run a web search"""
    return tavily_client.search(
        query,
        max_results=max_results,
        include_raw_content=include_raw_content,
        topic=topic,
    )
